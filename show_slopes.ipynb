# %%
import numpy as np
import matplotlib.pyplot as plt

PARAMETER_SETS = [
#    {"c": 0.0, "b": 0.11, "a": 0.0},
    {"c": 1.3, "b": 0.0222, "a": 0.0},
    {"c": 0.1, "b": -0.1, "a": 0.0},
    {"c": 1.9, "b": 0.046, "a": 0.0},
    {"c": 0.9, "b": 0.046, "a": 0.0},
    {"c": 1.1, "b": 0.046, "a": 0.0},
    {"c": 0.1, "b": 0.096, "a": 0.0},
    {"c": 0.5, "b": 0.046, "a": 0.0},
    {"c": 0.1, "b": 0.046, "a": 0.0},
    {"c": 0.7, "b": 0.046, "a": 0.0},
]
x = np.arange(0, 80, 1)
for p in PARAMETER_SETS:
    y = np.maximum(x * p["b"] + p["c"], 1)
    plt.plot(x, y, label=f"c={p['c']}, b={p['b']}, a={p['a']}")

plt.legend()
plt.xlabel("tree height")
plt.ylabel("Suppression radius")
plt.show()
